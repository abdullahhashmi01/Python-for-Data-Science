# %%
import numpy as np 
import pandas as pd

# %%
dict1 = { 
    "name" :['abdullah','hashmi','hussain','haider'] ,
    "marks" :[98,232,344,89],
    "city" :['lahore', 'vehari' ,'burewala', 'sahiwal']
}

# %%
df = pd.DataFrame(dict1)
df
# Out:
#        name  marks      city
# 0  abdullah     98    lahore
# 1    hashmi    232    vehari
# 2   hussain    344  burewala
# 3    haider     89   sahiwal

# %%
df.to_csv('friends.csv')

# %%
df.head(2)
# Out:
#        name  marks    city
# 0  abdullah     98  lahore
# 1    hashmi    232  vehari

# %%
df.tail(2)
# Out:
#       name  marks      city
# 2  hussain    344  burewala
# 3   haider     89   sahiwal

# %%
df.describe()
# Out:
#             marks
# count    4.000000
# mean   190.750000
# std    121.302308
# min     89.000000
# 25%     95.750000
# 50%    165.000000
# 75%    260.000000
# max    344.000000

# %%
abdullah = pd.read_csv("D:/Python_files/new_whether.csv")

# %%
abdullah
# Out:
#     Event  Temperature
# 0      10         39.0
# 1  Cloudy         39.0
# 2    Rain         38.0
# 3    Snow         36.0
# 4   Sunny         36.0

# %%
abdullah['Event'][4]
# Out:
# 'Sunny'

# %%
abdullah
# Out:
#     Event  Temperature
# 0      10         39.0
# 1  Cloudy         39.0
# 2    Rain         38.0
# 3    Snow         36.0
# 4   Sunny         36.0

# %%
abdullah.to_csv('names')

# %%
df =  pd.read_csv

# %%
df = pd.read_csv("D:/Python_files/weatherHistory.csv")

# %%
df
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
df.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
df.tail(3)
# Out:
#                       Formatted Date        Summary Precip Type  \
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 96450        22.038889                 22.038889      0.56             8.9838
# 96451        21.522222                 21.522222      0.60            10.5294
# 96452        20.438889                 20.438889      0.61             5.8765
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 96450                    30.0          16.1000         0.0
# 96451                    20.0          16.1000         0.0
# 96452                    39.0          15.5204         0.0
#
#        Pressure (millibars)                           Daily Summary
# 96450               1015.66  Partly cloudy starting in the morning.
# ...

# %%
df.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# ...

# %%
df['Temperature (C)']
# Out:
# 0         9.472222
# 1         9.355556
# 2         9.377778
# 3         8.288889
# 4         8.755556
#            ...
# 96448    26.016667
# 96449    24.583333
# 96450    22.038889
# 96451    21.522222
# 96452    20.438889
# Name: Temperature (C), Length: 96453, dtype: float64

# %%
ser = pd.Series(np.random.rand(34))

# %%
ser
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf = pd.DataFrame(np.random.rand(334,5), index= np.arange(334))

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.843479  0.637564  0.080648  0.650756  0.153819
# 1    0.021965  0.144217  0.752459  0.388095  0.261828
# 2    0.856546  0.696676  0.803100  0.127318  0.590571
# 3    0.358795  0.778209  0.074129  0.112953  0.457955
# 4    0.190977  0.503514  0.465429  0.505578  0.292568
# ..        ...       ...       ...       ...       ...
# 329  0.821852  0.050558  0.635265  0.706650  0.230957
# 330  0.699353  0.594698  0.961520  0.057575  0.931545
# 331  0.045944  0.111491  0.348951  0.718985  0.764639
# 332  0.478243  0.625121  0.507264  0.553646  0.898719
# 333  0.900875  0.380568  0.772264  0.389018  0.666045
#
# [334 rows x 5 columns]

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0.495013    0.482310    0.508422    0.485826    0.488622
# std      0.300233    0.290071    0.285787    0.289941    0.289537
# min      0.000360    0.001888    0.003761    0.001488    0.000538
# 25%      0.226703    0.227938    0.262304    0.235858    0.248239
# 50%      0.482299    0.485769    0.502834    0.474799    0.485449
# 75%      0.775730    0.736272    0.750562    0.731347    0.735367
# max      0.994312    0.999765    0.998862    0.998157    0.996764

# %%
newdf.to_numpy()
# Out:
# array([[0.84347928, 0.63756438, 0.08064801, 0.65075601, 0.15381884],
#        [0.02196461, 0.14421675, 0.752459  , 0.38809454, 0.2618278 ],
#        [0.85654601, 0.69667582, 0.80309992, 0.12731842, 0.59057119],
#        ...,
#        [0.04594373, 0.11149052, 0.34895054, 0.71898492, 0.7646386 ],
#        [0.478243  , 0.62512051, 0.50726428, 0.55364576, 0.8987188 ],
#        [0.90087504, 0.38056787, 0.77226428, 0.38901794, 0.66604549]],
#       shape=(334, 5))

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0