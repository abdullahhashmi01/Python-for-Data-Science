# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv("D:/python_files/Data sets/weatherHistory.csv")

# %% [markdown]
# Load and inspect

# %%
df
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
display(df)
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
df.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# ...

# %%
df.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %% [markdown]
# Basic analysis

# %%
Temp_mean=df['Temperature (C)'].mean()
Temp_meadian=df['Temperature (C)'].median()
print('Median of tempreture = ',Temp_mean)
print('Median of Tempreture = ',Temp_meadian)
# Out:
# Median of tempreture =  11.93267843751188
# Median of Tempreture =  12.0

# %%
min_windspeed=df['Wind Speed (km/h)'].min()
max_windspeed=df['Wind Speed (km/h)'].max()
print('Minimum wind speed = ',min_windspeed)
print('Maximum wind speed = ',max_windspeed)
# Out:
# Minimum wind speed =  0.0
# Maximum wind speed =  63.8526

# %% [markdown]
# Filtering Data

# %%
temp_above_25=df[df['Temperature (C)']>25]
display(temp_above_25)
# Out:
#                       Formatted Date        Summary Precip Type  \
# 448    2006-04-26 16:00:00.000 +0200  Mostly Cloudy        rain
# 729    2006-08-01 09:00:00.000 +0200  Partly Cloudy        rain
# 730    2006-08-01 10:00:00.000 +0200  Mostly Cloudy        rain
# 731    2006-08-01 11:00:00.000 +0200  Mostly Cloudy        rain
# 732    2006-08-01 12:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96444  2016-09-09 15:00:00.000 +0200  Partly Cloudy        rain
# 96445  2016-09-09 16:00:00.000 +0200  Partly Cloudy        rain
# 96446  2016-09-09 17:00:00.000 +0200  Partly Cloudy        rain
# 96447  2016-09-09 18:00:00.000 +0200  Partly Cloudy        rain
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 448          25.044444                 25.044444      0.32             3.5903
# ...

# %%
df['percentage_Humidity']=df['Humidity']*100
#display(df['percentage_Humidity'])
high_humidity=df[df['percentage_Humidity']>90]
display(high_humidity)
# Out:
#                       Formatted Date        Summary Precip Type  \
# 6      2006-04-01 06:00:00.000 +0200  Partly Cloudy        rain
# 53     2006-04-11 05:00:00.000 +0200       Overcast        rain
# 54     2006-04-11 06:00:00.000 +0200  Mostly Cloudy        rain
# 55     2006-04-11 07:00:00.000 +0200  Mostly Cloudy        rain
# 67     2006-04-11 19:00:00.000 +0200          Foggy        rain
# ...                              ...            ...         ...
# 96407  2016-09-08 02:00:00.000 +0200  Partly Cloudy        rain
# 96408  2016-09-08 03:00:00.000 +0200  Partly Cloudy        rain
# 96409  2016-09-08 04:00:00.000 +0200  Partly Cloudy        rain
# 96433  2016-09-09 04:00:00.000 +0200          Clear        rain
# 96435  2016-09-09 06:00:00.000 +0200          Clear        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 6             7.733333                  5.522222      0.95            12.3648
# ...

# %% [markdown]
# Data Range

# %%
start_date=df['Formatted Date'].min()
end_date=df['Formatted Date'].max()
print('The data is from ',start_date,' to ',end_date,' .')
# Out:
# The data is from  2006-01-01 00:00:00.000 +0100  to  2016-12-31 23:00:00.000 +0100  .

# %% [markdown]
# Level=Intermediate

# %% [markdown]
# Grouping and aggregation

# %%
grouped=df.groupby('Precip Type')[['Temperature (C)','Humidity']].mean()
print(grouped)
# Out:
#              Temperature (C)  Humidity
# Precip Type
# rain               13.852989  0.718699
# snow               -3.270885  0.863263

# %%
count=df.groupby('Precip Type')[['Temperature (C)','Humidity']].size()
print(count)
# Out:
# Precip Type
# rain    85224
# snow    10712
# dtype: int64

# %% [markdown]
# Correlation Matrix

# %%
Correlation_matrix=df[['Temperature (C)','Apparent Temperature (C)','Humidity','Wind Speed (km/h)']].corr()
display(Correlation_matrix)
# Out:
#                           Temperature (C)  Apparent Temperature (C)  Humidity  \
# Temperature (C)                  1.000000                  0.992629 -0.632255
# Apparent Temperature (C)         0.992629                  1.000000 -0.602571
# Humidity                        -0.632255                 -0.602571  1.000000
# Wind Speed (km/h)                0.008957                 -0.056650 -0.224951
#
#                           Wind Speed (km/h)
# Temperature (C)                    0.008957
# Apparent Temperature (C)          -0.056650
# Humidity                          -0.224951
# Wind Speed (km/h)                  1.000000

# %% [markdown]
# Handling missing values

# %%
df.isnull().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# percentage_Humidity           0
# dtype: int64

# %%
df.ffill(inplace=True)

# %%
df
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
df.isnull().sum()
# Out:
# Formatted Date              0
# Summary                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Loud Cover                  0
# Pressure (millibars)        0
# Daily Summary               0
# percentage_Humidity         0
# dtype: int64

# %% [markdown]
# Weather summary analysis

# %%
unique_count=df['Summary'].nunique()
print('Number of unique daily summary = ',unique_count)
# Out:
# Number of unique daily summary =  27

# %%
most_common=df['Summary'].value_counts().idxmax()
print('most common daily summary = ',most_common)
# Out:
# most common daily summary =  Partly Cloudy

# %%
mean_value=df.groupby('Summary')['Temperature (C)'].mean()
hottest_summary=mean_value.idxmax()
print('Highest average tempreture = ',hottest_summary)
# Out:
# Highest average tempreture =  Dry

# %% [markdown]
# Advanced Filtering

# %%
Filtered_data=df[(df['Visibility (km)']<10) & (df['Wind Speed (km/h)']>20)]
display('Filtered data = ',Filtered_data)
# Out:
# 'Filtered data = '
#                       Formatted Date              Summary Precip Type  \
# 35     2006-04-10 11:00:00.000 +0200        Mostly Cloudy        rain
# 36     2006-04-10 12:00:00.000 +0200        Mostly Cloudy        rain
# 37     2006-04-10 13:00:00.000 +0200        Mostly Cloudy        rain
# 39     2006-04-10 15:00:00.000 +0200        Mostly Cloudy        rain
# 40     2006-04-10 16:00:00.000 +0200        Mostly Cloudy        rain
# ...                              ...                  ...         ...
# 96031  2016-09-20 10:00:00.000 +0200        Partly Cloudy        rain
# 96033  2016-09-20 12:00:00.000 +0200        Mostly Cloudy        rain
# 96342  2016-09-05 09:00:00.000 +0200             Overcast        rain
# 96343  2016-09-05 10:00:00.000 +0200  Breezy and Overcast        rain
# 96346  2016-09-05 13:00:00.000 +0200             Overcast        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %%
highest_pressure=df.loc[df['Pressure (millibars)'].idxmax()]
display(highest_pressure)
# Out:
# Formatted Date                                  2008-02-17 08:00:00.000 +0100
# Summary                                                                 Clear
# Precip Type                                                              snow
# Temperature (C)                                                     -8.838889
# Apparent Temperature (C)                                           -14.627778
# Humidity                                                                 0.61
# Wind Speed (km/h)                                                     12.4936
# Wind Bearing (degrees)                                                  349.0
# Visibility (km)                                                         9.982
# Loud Cover                                                                0.0
# Pressure (millibars)                                                  1046.38
# Daily Summary               Partly cloudy starting in the morning continui...
# ...
